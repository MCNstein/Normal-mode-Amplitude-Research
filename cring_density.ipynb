# %%
import pickle 
import numpy as np
import matplotlib.pyplot as plt

class AttributeDict(dict):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.__dict__ = self

class psd:
    def __init__(self):
        self.radius=radius

# %%
#pickletools('C_rng_size_dist_params_06_20_2019.pkl')
file=open('C_rng_size_dist_params_06_28_2019.pkl','rb')
#picklefile
data = pickle.load(file)
data
l=dir(data)
print(l)
# Out:
# ['Nthin', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'amax', 'amin', 'chi2', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'n0', 'pop', 'popitem', 'q', 'radius', 'setdefault', 'sig', 'update', 'values']

# %%
#sig1=data.sig1
amin=data.amin
amax=data.amax
n0=data.n0
radi=data.radius
q=data.q
#tau=data.tau_normal

# %%
q
# Out:
# array([3.09863833, 3.09557886, 3.09251939, ..., 3.16694517, 3.13563598,
#        3.19748764])

# %%
plt.figure(figsize=[20,5])
plt.plot(radi/1e3, amax, 'k.')
plt.ylabel('amax (m)')
plt.show()
plt.figure(figsize=[20,5])
plt.plot(radi/1e3, amin,'k.')
plt.ylim([0,.01])
plt.ylabel('amin (m)')
plt.show()
plt.figure(figsize=[20,5])
plt.plot(radi/1e3, q,'k.')
plt.ylim([2.5,3.5])
plt.ylabel('q')
plt.show()
plt.figure(figsize=[20,5])
plt.plot(radi/1e3, tau,'k.')
plt.ylabel('tau_normal')
plt.ylim([0,.5])
plt.show()
plt.figure(figsize=[20,5])
plt.plot(radi/1e3, sig1, 'k.')
plt.ylabel('nominal sigma (g/cm^2)')
plt.ylim([0,12])
plt.show()
plt.figure(figsize=[20,5])
plt.plot(radi/1e3, tau/sig1, 'k.')
plt.ylabel('nominal kappa (cm^2/g)')
plt.ylim([0,.1])
plt.show()
plt.figure(figsize=[20,5])
plt.plot(radi/1e3, 0.75/tau*sig1/.236/100, 'k.')
plt.ylim([0,2])
plt.ylabel('reff (m)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_52084/3442381033.py in <module>
#      14 plt.show()
#      15 plt.figure(figsize=[20,5])
# ---> 16 plt.plot(radi/1e3, tau,'k.')
#      17 plt.ylabel('tau_normal')
#      18 plt.ylim([0,.5])
#
# NameError: name 'tau' is not defined

# %%
from scipy.special import lambertw

# %%
foo=(radi==86800)
print(data.tau_normal[foo]/sig1[foo])
print(sig1[foo])
# Out:
# [0.04785136]
# [0.86815646]

# %%
Reff=0.75/data.tau_normal*sig1/.236

# %%
foo=(radi==86800)
print(data.tau_normal[foo]/sig1[foo])
print(sig1[foo])
print(Reff[foo])
# Out:
# [0.04785136]
# [0.86815646]
# [66.413289]

# %%
reff2=(3-q)/(4-q)*(amax**(4-q)-amin**(4-q))/(amax**(3-q)-amin**(3-q))*100
# Out:
# /var/folders/lj/3p5r7psn5czdlfnyz_18s59h0000gn/T/ipykernel_32695/1675370676.py:1: RuntimeWarning: invalid value encountered in true_divide
#   reff2=(3-q)/(4-q)*(amax**(4-q)-amin**(4-q))/(amax**(3-q)-amin**(3-q))*100

# %%
plt.figure(figsize=[20,5])
plt.plot(radi/1e3, Reff/100, 'k.')
plt.plot(radi/1e3,reff2/100, 'g.')
plt.ylim([0,2])
plt.ylabel('reff (m)')
plt.show()

# %%
plt.figure(figsize=[20,5])
plt.plot(radi/1e3, reff2/Reff, 'k.')
plt.ylim([.5,1.5])
plt.ylabel('reff (m)')
plt.show()

# %%
foo=(radi==86800)
print(data.tau_normal[foo]/sig1[foo])
print(sig1[foo])
print(Reff[foo])
print(reff2[foo])
# Out:
# [0.04785136]
# [0.86815646]
# [66.413289]
# [70.26325427]

# %%
rnoms=[74500,74740,74750,74760,75140,76020,76440,76460,77340,
       78510,79040,79550,80490,80990,81020,81020,81330,81430,
       81960,82010,82060,82210,82530,82600,83090,83630,84150,
       84640,87190,74890,85100,87650,88430,89880,89890,
       84250,84830,85710,86420,86560,86800]

# %%
for i in range(len(rnoms)):
    foo=(radi==rnoms[i])
    print(rnoms[i], Reff[foo],reff2[foo])
# Out:
# 74500 [45.45754502] [30.52533693]
# 74740 [31.59372673] [35.66276542]
# 74750 [95.95962442] [101.59430572]
# 74760 [79.38154449] [69.58621849]
# 75140 [79.35674613] [79.16075932]
# 76020 [86.3805845] [101.30662348]
# 76440 [60.76133985] [69.23212406]
# 76460 [92.7552593] [119.11205779]
# 77340 [91.93274077] [102.5544883]
# 78510 [86.48698364] [109.4132476]
# 79040 [85.65668605] [94.32231811]
# 79550 [70.10567528] [75.27356144]
# 80490 [75.46398726] [81.84391332]
# 80990 [91.38412477] [96.73929288]
# 81020 [74.24699511] [81.27035858]
# 81020 [74.24699511] [81.27035858]
# 81330 [82.43542555] [92.65532724]
# 81430 [83.39394093] [91.4993368]
# 81960 [97.43253471] [104.52474138]
# 82010 [93.71303643] [100.17492503]
# 82060 [78.94386089] [94.89818197]
# 82210 [74.15997574] [87.0864635]
# 82530 [86.86897697] [91.91081532]
# 82600 [108.36760698] [118.42109183]
# 83090 [98.5284166] [109.19954702]
# 83630 [94.24928407] [111.12463038]
# 84150 [80.53217725] [82.54688508]
# ...
